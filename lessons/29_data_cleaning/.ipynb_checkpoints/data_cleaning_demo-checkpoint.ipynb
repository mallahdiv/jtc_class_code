# %% [markdown]
# # Data cleaning
#
# ALL PANDAS
#
# * Select specific rows and columns
# * Changing column names
# * Making new columns/removing columns
# * Work with missing data -- replacing/removing missing parts
# * Exporting data back to a csv file

# %%
import pandas as pd

# %%
reviews = pd.read_csv('../../datasets/musical_instrument_reviews.csv')

# show top 5 rows of the data frame
reviews.head()
# Out:
#        reviewerID                                      reviewerName  \
# 0  A2IBPI20UZIR0U  cassandra tu "Yeah, well, that's just like, u...
# 1  A14VAT5EAX3D9S                                              Jake
# 2  A195EZSQDW3E21                     Rick Bennette "Rick Bennette"
# 3  A2C00NNG1ZQQG2                         RustyBill "Sunday Rocker"
# 4   A94QU4C90B1AX                                     SEAN MASLANKA
#
#                                           reviewText  overall  \
# 0  Not much to write about here, but it does exac...      5.0
# 1  The product does exactly as it should and is q...      5.0
# 2  The primary job of this device is to block the...      5.0
# 3  Nice windscreen protects my MXL mic and preven...      5.0
# 4  This pop filter is great. It looks and perform...      5.0
#
#                                  summary   reviewTime  reviewWords
# 0                                   good  02 28, 2014           51
# ...

# %% [markdown]
# # Select specific columns
#
# * 1 pair of hard brackets -- selecting just 1 column as a series
# * 2 pairs of hard brackets -- 1 or more columns as a dataframe

# %%
one_column = reviews[['reviewerID']]
one_column
# Out:
#          reviewerID
# 0    A2IBPI20UZIR0U
# 1    A14VAT5EAX3D9S
# 2    A195EZSQDW3E21
# 3    A2C00NNG1ZQQG2
# 4     A94QU4C90B1AX
# ..              ...
# 495   A2RVY2GDMZHH4
# 496   AJGD0VSCUJUP5
# 497  A3EZEP0FX5BC1P
# 498  A3C9F3SZWLWDZF
# 499   AHMEG9CAAT2KF
#
# [500 rows x 1 columns]

# %%
columns_i_want = ['reviewerID', 'overall', 'summary']
two_columns = reviews[columns_i_want]
two_columns.head()
# Out:
#        reviewerID  overall                                summary
# 0  A2IBPI20UZIR0U      5.0                                   good
# 1  A14VAT5EAX3D9S      5.0                                   Jake
# 2  A195EZSQDW3E21      5.0                   It Does The Job Well
# 3  A2C00NNG1ZQQG2      5.0          GOOD WINDSCREEN FOR THE MONEY
# 4   A94QU4C90B1AX      5.0  No more pops when I record my vocals.

# %%
# specifying columns to get rid of
reviews.drop(columns = ['reviewTime'])
# Out:
#          reviewerID                                      reviewerName  \
# 0    A2IBPI20UZIR0U  cassandra tu "Yeah, well, that's just like, u...
# 1    A14VAT5EAX3D9S                                              Jake
# 2    A195EZSQDW3E21                     Rick Bennette "Rick Bennette"
# 3    A2C00NNG1ZQQG2                         RustyBill "Sunday Rocker"
# 4     A94QU4C90B1AX                                     SEAN MASLANKA
# ..              ...                                               ...
# 495   A2RVY2GDMZHH4                                          puddytat
# 496   AJGD0VSCUJUP5                                         Squidsmom
# 497  A3EZEP0FX5BC1P                             A Conrad "Ask Conrad"
# 498  A3C9F3SZWLWDZF                                       B. Benamati
# 499   AHMEG9CAAT2KF                                               Bon
#
#                                             reviewText  overall  \
# ...

# %% [markdown]
# # Select specific rows

# %% [markdown]
# `iloc()` - select rows by their index position

# %%
reviews.iloc[2:4, :]
# Out:
#        reviewerID                   reviewerName  \
# 2  A195EZSQDW3E21  Rick Bennette "Rick Bennette"
# 3  A2C00NNG1ZQQG2      RustyBill "Sunday Rocker"
#
#                                           reviewText  overall  \
# 2  The primary job of this device is to block the...      5.0
# 3  Nice windscreen protects my MXL mic and preven...      5.0
#
#                          summary   reviewTime  reviewWords
# 2           It Does The Job Well  08 28, 2013           77
# 3  GOOD WINDSCREEN FOR THE MONEY  02 14, 2014           35

# %% [markdown]
# #### Filtering rows based on the DATA in the dataframe
#
# we only want rows where reivews are longer than 50 words
#
#
# involves LOGIC -- we only want rows where `CONDITION` is true

# %%
# a column + a logical condition
reviews['reviewWords'] > 50
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497     True
# 498    False
# 499    False
# Name: reviewWords, Length: 500, dtype: bool

# %%
# dataframename[dataframename['colummnd'] > value]
# dataframename[logical statement applied to 1 column]
reviews_over_50_words = reviews[reviews['reviewWords'] > 50]

# %%
reviews_over_50_words.head()
# Out:
#         reviewerID                                      reviewerName  \
# 0   A2IBPI20UZIR0U  cassandra tu "Yeah, well, that's just like, u...
# 1   A14VAT5EAX3D9S                                              Jake
# 2   A195EZSQDW3E21                     Rick Bennette "Rick Bennette"
# 7    AJNFQI3YR6XJ5                                 Fender Guy "Rick"
# 10  A2NYK9KWFMJV4Y                       Mike Tarrani "Jazz Drummer"
#
#                                            reviewText  overall  \
# 0   Not much to write about here, but it does exac...      5.0
# 1   The product does exactly as it should and is q...      5.0
# 2   The primary job of this device is to block the...      5.0
# 7   I now use this cable to run from the output of...      3.0
# 10  Monster makes a wide array of cables, includin...      5.0
#
#                                               summary   reviewTime  \
# 0                                                good  02 28, 2014
# ...

# %% [markdown]
# # Filter only the 'good' reivews -- lets see what the people who reallly like the product are saying
#
# Only reivews where the `overall` score was 4 or greater

# %%
good_reviews = reviews[reviews['overall'] >= 4]

# %%
good_reviews.describe()
# Out:
#           overall  reviewWords
# count  451.000000   451.000000
# mean     4.725055    86.119734
# std      0.446982   107.781997
# min      4.000000     7.000000
# 25%      4.000000    30.000000
# 50%      5.000000    49.000000
# 75%      5.000000    90.500000
# max      5.000000   915.000000

# %%
reviews.describe()
# Out:
#           overall  reviewWords
# count  496.000000   500.000000
# mean     4.526210    89.902000
# std      0.790933   121.328949
# min      1.000000     7.000000
# 25%      4.000000    29.000000
# 50%      5.000000    48.000000
# 75%      5.000000    97.000000
# max      5.000000  1290.000000

# %%
reviews.head()
# Out:
#        reviewerID                                      reviewerName  \
# 0  A2IBPI20UZIR0U  cassandra tu "Yeah, well, that's just like, u...
# 1  A14VAT5EAX3D9S                                              Jake
# 2  A195EZSQDW3E21                     Rick Bennette "Rick Bennette"
# 3  A2C00NNG1ZQQG2                         RustyBill "Sunday Rocker"
# 4   A94QU4C90B1AX                                     SEAN MASLANKA
#
#                                           reviewText  overall  \
# 0  Not much to write about here, but it does exac...      5.0
# 1  The product does exactly as it should and is q...      5.0
# 2  The primary job of this device is to block the...      5.0
# 3  Nice windscreen protects my MXL mic and preven...      5.0
# 4  This pop filter is great. It looks and perform...      5.0
#
#                                  summary   reviewTime  reviewWords
# 0                                   good  02 28, 2014           51
# ...

# %%
# string column example -- filter the dataframe where the summary column has the value 'good'
reviews[reviews['summary'] == 'good']
# Out:
#          reviewerID                                      reviewerName  \
# 0    A2IBPI20UZIR0U  cassandra tu "Yeah, well, that's just like, u...
# 469   A4BTCECGQAIUI                                   Amazon Customer
#
#                                             reviewText  overall summary  \
# 0    Not much to write about here, but it does exac...      5.0    good
# 469  I got this pedal cause is not so expensive, an...      5.0    good
#
#       reviewTime  reviewWords
# 0    02 28, 2014           51
# 469   04 9, 2013           48

# %% [markdown]
# # Changing DataFrame column names

# %%
reviews.head()
# Out:
#        reviewerID                                      reviewerName  \
# 0  A2IBPI20UZIR0U  cassandra tu "Yeah, well, that's just like, u...
# 1  A14VAT5EAX3D9S                                              Jake
# 2  A195EZSQDW3E21                     Rick Bennette "Rick Bennette"
# 3  A2C00NNG1ZQQG2                         RustyBill "Sunday Rocker"
# 4   A94QU4C90B1AX                                     SEAN MASLANKA
#
#                                           reviewText  overall  \
# 0  Not much to write about here, but it does exac...      5.0
# 1  The product does exactly as it should and is q...      5.0
# 2  The primary job of this device is to block the...      5.0
# 3  Nice windscreen protects my MXL mic and preven...      5.0
# 4  This pop filter is great. It looks and perform...      5.0
#
#                                  summary   reviewTime  reviewWords
# 0                                   good  02 28, 2014           51
# ...

# %% [markdown]
# Rename columns with a dictionary, where format is `old_column:new_column`

# %%
reviews.rename(columns = {'reviewText':'text', 'reviewTime': 'date'}, inplace = True)

# %% [markdown]
# # Add a new column

# %% [markdown]
# a column that just has a constant value

# %%
reviews['zeros'] = 0
reviews['analyst_name'] = 'Paul'

# %%
reviews.head()
# Out:
#        reviewerID                                      reviewerName  \
# 0  A2IBPI20UZIR0U  cassandra tu "Yeah, well, that's just like, u...
# 1  A14VAT5EAX3D9S                                              Jake
# 2  A195EZSQDW3E21                     Rick Bennette "Rick Bennette"
# 3  A2C00NNG1ZQQG2                         RustyBill "Sunday Rocker"
# 4   A94QU4C90B1AX                                     SEAN MASLANKA
#
#                                                 text  overall  \
# 0  Not much to write about here, but it does exac...      5.0
# 1  The product does exactly as it should and is q...      5.0
# 2  The primary job of this device is to block the...      5.0
# 3  Nice windscreen protects my MXL mic and preven...      5.0
# 4  This pop filter is great. It looks and perform...      5.0
#
#                                  summary         date  reviewWords  zeros  \
# 0                                   good  02 28, 2014           51      0
# ...

# %% [markdown]
# column based on math from two other columns

# %%
reviews['super_score'] = reviews['overall'] * reviews['reviewWords']
reviews['score2'] = reviews['overall']*10.1

# %%
reviews
# Out:
#          reviewerID                                      reviewerName  \
# 0    A2IBPI20UZIR0U  cassandra tu "Yeah, well, that's just like, u...
# 1    A14VAT5EAX3D9S                                              Jake
# 2    A195EZSQDW3E21                     Rick Bennette "Rick Bennette"
# 3    A2C00NNG1ZQQG2                         RustyBill "Sunday Rocker"
# 4     A94QU4C90B1AX                                     SEAN MASLANKA
# ..              ...                                               ...
# 495   A2RVY2GDMZHH4                                          puddytat
# 496   AJGD0VSCUJUP5                                         Squidsmom
# 497  A3EZEP0FX5BC1P                             A Conrad "Ask Conrad"
# 498  A3C9F3SZWLWDZF                                       B. Benamati
# 499   AHMEG9CAAT2KF                                               Bon
#
#                                                   text  overall  \
# ...

# %% [markdown]
# make a column based on logic from another column (boolean column)

# %%
reviews['words50'] = reviews['reviewWords'] > 50

# %%
reviews.head()
# Out:
#        reviewerID                                      reviewerName  \
# 0  A2IBPI20UZIR0U  cassandra tu "Yeah, well, that's just like, u...
# 1  A14VAT5EAX3D9S                                              Jake
# 2  A195EZSQDW3E21                     Rick Bennette "Rick Bennette"
# 3  A2C00NNG1ZQQG2                         RustyBill "Sunday Rocker"
# 4   A94QU4C90B1AX                                     SEAN MASLANKA
#
#                                                 text  overall  \
# 0  Not much to write about here, but it does exac...      5.0
# 1  The product does exactly as it should and is q...      5.0
# 2  The primary job of this device is to block the...      5.0
# 3  Nice windscreen protects my MXL mic and preven...      5.0
# 4  This pop filter is great. It looks and perform...      5.0
#
#                                  summary         date  reviewWords  zeros  \
# 0                                   good  02 28, 2014           51      0
# ...

# %% [markdown]
# # Finding/dealing with missing data
#
# `.isnull()` -- a method for BOTH dataframes, and series
#
# returns `False` if there is data, and `True` if the data is missing (cell is blank)

# %%
reviews.isnull()
# Out:
#      reviewerID  reviewerName   text  overall  summary   date  reviewWords  \
# 0         False         False  False    False    False  False        False
# 1         False         False  False    False    False  False        False
# 2         False         False  False    False    False  False        False
# 3         False         False  False    False    False  False        False
# 4         False         False  False    False    False  False        False
# ..          ...           ...    ...      ...      ...    ...          ...
# 495       False         False  False    False    False  False        False
# 496       False         False  False    False    False  False        False
# 497       False         False  False    False    False  False        False
# 498       False         False  False    False    False  False        False
# 499       False         False  False    False    False  False        False
#
#      zeros  analyst_name  super_score  score2  words50
# ...

# %% [markdown]
# # How many missing values in each column?

# %%
reviews.isnull().sum()
# Out:
# reviewerID      0
# reviewerName    4
# text            0
# overall         4
# summary         3
# date            0
# reviewWords     0
# zeros           0
# analyst_name    0
# super_score     4
# score2          4
# words50         0
# dtype: int64

# %%
# show the rows where reviewerName is missing
reviews[reviews['reviewerName'].isnull()]
# Out:
#          reviewerID reviewerName  \
# 41    AA5TINW2RJ195          NaN
# 263  A14VAT5EAX3D9S          NaN
# 264   A2RVY2GDMZHH4          NaN
# 432  A3BMYEA3J6RBVV          NaN
#
#                                                   text  overall  \
# 41             Good quality cable and sounds very good      5.0
# 263  It is exactly what you need in a capo! You can...      5.0
# 264  Love these capos and nice that you can get the...      5.0
# 432    Bought it as a gift. Friend loved it very much.      5.0
#
#                        summary         date  reviewWords  zeros analyst_name  \
# 41                  Five Stars  07 15, 2014            7      0         Paul
# 263                      Great   04 2, 2013           82      0         Paul
# 264         Always great Kyser  12 28, 2012           23      0         Paul
# 432  Friend loved it very much  07 13, 2014           10      0         Paul
#
#      super_score  score2  words50
# 41          35.0    50.5    False
# ...

# %%
# show the rows where reviewerName is NOT missing
# TAKE OUT those rows, and save into a new dataframe called reviews_clean
reviews_clean = reviews[-reviews['reviewerName'].isnull()]

# %%
reviews_clean
# Out:
#          reviewerID                                      reviewerName  \
# 0    A2IBPI20UZIR0U  cassandra tu "Yeah, well, that's just like, u...
# 1    A14VAT5EAX3D9S                                              Jake
# 2    A195EZSQDW3E21                     Rick Bennette "Rick Bennette"
# 3    A2C00NNG1ZQQG2                         RustyBill "Sunday Rocker"
# 4     A94QU4C90B1AX                                     SEAN MASLANKA
# ..              ...                                               ...
# 495   A2RVY2GDMZHH4                                          puddytat
# 496   AJGD0VSCUJUP5                                         Squidsmom
# 497  A3EZEP0FX5BC1P                             A Conrad "Ask Conrad"
# 498  A3C9F3SZWLWDZF                                       B. Benamati
# 499   AHMEG9CAAT2KF                                               Bon
#
#                                                   text  overall  \
# ...

# %%
reviews_clean.isnull().sum()
# Out:
# reviewerID      0
# reviewerName    0
# text            0
# overall         4
# summary         3
# date            0
# reviewWords     0
# zeros           0
# analyst_name    0
# super_score     4
# score2          4
# words50         0
# dtype: int64

# %%
reviews_clean = reviews_clean[-reviews_clean['overall'].isnull()]

# %%
reviews_clean.isnull().sum()
# Out:
# reviewerID      0
# reviewerName    0
# text            0
# overall         0
# summary         3
# date            0
# reviewWords     0
# zeros           0
# analyst_name    0
# super_score     0
# score2          0
# words50         0
# dtype: int64

# %% [markdown]
# # Save to csv file

# %%
reviews_clean.to_csv('../../datasets/reviews_clean.csv', index = False)

# %%
# %matplotlib inline

# %%
reviews.hist('overall')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x102928f10>]],
#       dtype=object)

# %%
reviews_clean.hist('overall')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x113375ed0>]],
#       dtype=object)
