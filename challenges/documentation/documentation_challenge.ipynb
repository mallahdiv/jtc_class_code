# %% [markdown]
# # 1. Import pandas and load the `billboard_1978.csv` dataset into a DataFrame
#
# As a reminder, `billboard_1978.csv` is in your `jtc_class_code/datasets` folder

# %%
import pandas as pd
billboard = pd.read_csv('\\Users\\there\\Desktop\\JTC_Class_Code\\datasets\\billboard_1978.csv')

# %% [markdown]
# # 2. Print out the top 7 rows of the DataFrame

# %% [markdown]
# ##Printed the first 7 rows of the Dataframe##

# %%
billboard.head(7)
# Out:
#    Year  Hot_Singles_Rank                    Title       Artist    Genre  \
# 0  1978                 1         "Shadow Dancing"    Andy Gibb      Pop
# 1  1978                 2            "Night Fever"     Bee Gees      Pop
# 2  1978                 3   "You Light Up My Life"  Debby Boone  Country
# 3  1978                 4          "Stayin' Alive"     Bee Gees      Pop
# 4  1978                 5      "Kiss You All Over"        Exile  Country
# 5  1978                 6  "How Deep Is Your Love"     Bee Gees      Pop
# 6  1978                 7         "Baby Come Back"       Player      Pop
#
#   Weeks_On_Chart  Peak_Chart_Position Maj_Min  BPM
# 0             25                    1     Min  102
# 1             20                    1     Min  110
# 2             25                    1     Maj   78
# 3             27                    1     Min  103
# 4             23                    1     Maj  104
# 5             33                    1     Maj  105
# 6             32                    1     Maj   78

# %% [markdown]
# # 3. Use the pandas docs to figure out how to sort the DataFrame so the fastest songs (highest BPM values) are at the top. Also, sort the DataFrame 'in place' without having to assign to a variable

# %%
billboard.sort_values(by='BPM', ascending =False, inplace = True)
billboard
# Out:
#     Year  Hot_Singles_Rank                 Title  \
# 74  1978                75  "Always and Forever"
# 98  1978                99    "Hollywood Nights"
# 76  1978                77     "Serpentine Fire"
# 93  1978                94       "Turn to Stone"
# 69  1978                70    "What's Your Name"
# ..   ...               ...                   ...
# 11  1978                12          "I Go Crazy"
# 80  1978                81     "Bluer Than Blue"
# 97  1978                98     "We're All Alone"
# 33  1978                34          "Last Dance"
# 62  1978                63       "You Needed Me"
#
#                                 Artist     Genre Weeks_On_Chart  \
# 74                            Heatwave  R&B/Soul             20
# 98  Bob Seger & The Silver Bullet Band      Rock             13
# 76                  Earth, Wind & Fire  R&B/Soul             18
# 93            Electric Light Orchestra      Rock             15
# 69                      Lynyrd Skynyrd      Rock             18
# ..                                 ...       ...            ...
# 11                          Paul Davis       Pop             40
# 80                     Michael Johnson       Pop             16
# 97                       Rita Coolidge       Pop             20
# 33                        Donna Summer       Pop             21
# 62                         Anne Murray   Country             26
#
#     Peak_Chart_Position Maj_Min  BPM
# 74                   18     Maj  156
# 98                   12     Maj  150
# 76                   13     Maj  140
# 93                   13     Maj  138
# 69                   13     Maj  138
# ..                  ...     ...  ...
# 11                    7     Maj   70
# 80                   12     Maj   66
# 97                    7     Maj   66
# 33                    3     Maj   64
# 62                    1     Maj   64
#
# [100 rows x 9 columns]

# %% [markdown]
# # 4. Use the pandas docs to find out how to remove the `Genre` and `Maj_Min` columns from the DataFrame (while keeping the rest)
#
# Make sure you save the resulting DataFrame, either in place, or by assigning a new variable
#
# Hint: one way to phrase this is 'dropping' columns

# %%
b = billboard.drop(columns=['Genre', 'Maj_Min'])
b
# Out:
#     Year  Hot_Singles_Rank                 Title  \
# 74  1978                75  "Always and Forever"
# 98  1978                99    "Hollywood Nights"
# 76  1978                77     "Serpentine Fire"
# 93  1978                94       "Turn to Stone"
# 69  1978                70    "What's Your Name"
# ..   ...               ...                   ...
# 11  1978                12          "I Go Crazy"
# 80  1978                81     "Bluer Than Blue"
# 97  1978                98     "We're All Alone"
# 33  1978                34          "Last Dance"
# 62  1978                63       "You Needed Me"
#
#                                 Artist Weeks_On_Chart  Peak_Chart_Position  \
# 74                            Heatwave             20                   18
# 98  Bob Seger & The Silver Bullet Band             13                   12
# 76                  Earth, Wind & Fire             18                   13
# 93            Electric Light Orchestra             15                   13
# 69                      Lynyrd Skynyrd             18                   13
# ..                                 ...            ...                  ...
# 11                          Paul Davis             40                    7
# 80                     Michael Johnson             16                   12
# 97                       Rita Coolidge             20                    7
# 33                        Donna Summer             21                    3
# 62                         Anne Murray             26                    1
#
#     BPM
# 74  156
# 98  150
# 76  140
# 93  138
# 69  138
# ..  ...
# 11   70
# 80   66
# 97   66
# 33   64
# 62   64
#
# [100 rows x 7 columns]

# %% [markdown]
# # 5. Using [this page from the Pandas documentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.lower.html) as a starting point, find a way to make song titles all lower case and song artists all caps.
#
# Remember, each column in a DataFrame object is a data type called `Series` (or `pandas.Series`)

# %%
billboard['Title'] = billboard['Title'].str.lower()
billboard
# Out:
#     Year  Hot_Singles_Rank                 Title  \
# 74  1978                75  "always and forever"
# 98  1978                99    "hollywood nights"
# 76  1978                77     "serpentine fire"
# 93  1978                94       "turn to stone"
# 69  1978                70    "what's your name"
# ..   ...               ...                   ...
# 11  1978                12          "i go crazy"
# 80  1978                81     "bluer than blue"
# 97  1978                98     "we're all alone"
# 33  1978                34          "last dance"
# 62  1978                63       "you needed me"
#
#                                 Artist     Genre Weeks_On_Chart  \
# 74                            Heatwave  R&B/Soul             20
# 98  Bob Seger & The Silver Bullet Band      Rock             13
# 76                  Earth, Wind & Fire  R&B/Soul             18
# 93            Electric Light Orchestra      Rock             15
# 69                      Lynyrd Skynyrd      Rock             18
# ..                                 ...       ...            ...
# 11                          Paul Davis       Pop             40
# 80                     Michael Johnson       Pop             16
# 97                       Rita Coolidge       Pop             20
# 33                        Donna Summer       Pop             21
# 62                         Anne Murray   Country             26
#
#     Peak_Chart_Position Maj_Min  BPM
# 74                   18     Maj  156
# 98                   12     Maj  150
# 76                   13     Maj  140
# 93                   13     Maj  138
# 69                   13     Maj  138
# ..                  ...     ...  ...
# 11                    7     Maj   70
# 80                   12     Maj   66
# 97                    7     Maj   66
# 33                    3     Maj   64
# 62                    1     Maj   64
#
# [100 rows x 9 columns]

# %%
billboard['Artist'] =billboard['Artist'].str.upper()
billboard
# Out:
#     Year  Hot_Singles_Rank                 Title  \
# 74  1978                75  "always and forever"
# 98  1978                99    "hollywood nights"
# 76  1978                77     "serpentine fire"
# 93  1978                94       "turn to stone"
# 69  1978                70    "what's your name"
# ..   ...               ...                   ...
# 11  1978                12          "i go crazy"
# 80  1978                81     "bluer than blue"
# 97  1978                98     "we're all alone"
# 33  1978                34          "last dance"
# 62  1978                63       "you needed me"
#
#                                 Artist     Genre Weeks_On_Chart  \
# 74                            HEATWAVE  R&B/Soul             20
# 98  BOB SEGER & THE SILVER BULLET BAND      Rock             13
# 76                  EARTH, WIND & FIRE  R&B/Soul             18
# 93            ELECTRIC LIGHT ORCHESTRA      Rock             15
# 69                      LYNYRD SKYNYRD      Rock             18
# ..                                 ...       ...            ...
# 11                          PAUL DAVIS       Pop             40
# 80                     MICHAEL JOHNSON       Pop             16
# 97                       RITA COOLIDGE       Pop             20
# 33                        DONNA SUMMER       Pop             21
# 62                         ANNE MURRAY   Country             26
#
#     Peak_Chart_Position Maj_Min  BPM
# 74                   18     Maj  156
# 98                   12     Maj  150
# 76                   13     Maj  140
# 93                   13     Maj  138
# 69                   13     Maj  138
# ..                  ...     ...  ...
# 11                    7     Maj   70
# 80                   12     Maj   66
# 97                    7     Maj   66
# 33                    3     Maj   64
# 62                    1     Maj   64
#
# [100 rows x 9 columns]

# %% [markdown]
# # 6. Using the Pandas docs, find a way to export your finished DataFrame to a new csv file called `billboard_1978_cleaned.csv`
#
# #### Bonus: can you get this file to be output right back into the `jtc_class_code/datasets/` folder?

# %%
billboard.to_csv(r'\Users\there\Desktop\JTC_Class_Code\datasets\billboard_1978_clean.csv')

# %% [markdown]
# # 7. Wrap-up: comment your code (including pasting in any links to the docs where you found solutions) and push your .ipynb file to github
#
# Congrats on finishing this challenge!
